# %%
import re
import shutil
from pathlib import Path
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from tqdm.notebook import tqdm

# %config InlineBackend.figure_format='retina'
plt.rcParams["figure.dpi"] = 150

# %load_ext autoreload
# %autoreload 2

# %%
df = pd.DataFrame()
df['company_codes'] = ['company/5097914', 'company/12956739', 'company/3919615']
df.to_excel('/Users/user/Downloads/company_codes.xlsx')

# %%
import yaml

with open('/Users/user/Main/Repos/llm-editor/backend/src/model/pre_prompts.yaml', 'r') as f:
    d = yaml.safe_load(f)

# %%
import requests

def query(payload, model_id, api_token):
	headers = {"Authorization": f"Bearer {api_token}"}
	API_URL = f"https://api-inference.huggingface.co/models/{model_id}"
	response = requests.post(API_URL, headers=headers, json=payload)
	return response.json()

model_id = "Geotrend/distilbert-base-ru-cased"
api_token = "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" # get yours at hf.co/settings/tokens
data = query("Для жизни достаточно [MASK].", model_id, api_token)
data
# Out:
# [{'score': 0.17458999156951904,
#   'token': 5105,
#   'token_str': 'мало',
#   'sequence': 'Для жизни достаточно мало.'},
#  {'score': 0.06354586780071259,
#   'token': 6901,
#   'token_str': 'достаточно',
#   'sequence': 'Для жизни достаточно достаточно.'},
#  {'score': 0.05858616158366203,
#   'token': 6668,
#   'token_str': 'хорошо',
#   'sequence': 'Для жизни достаточно хорошо.'},
#  {'score': 0.053913865238428116,
#   'token': 7288,
#   'token_str': 'быстро',
#   'sequence': 'Для жизни достаточно быстро.'},
#  {'score': 0.04464755579829216,
#   'token': 5301,
#   'token_str': 'мала',
#   'sequence': 'Для жизни достаточно мала.'}]

# %%
import requests

def query(payload):
	API_URL = "https://51.250.110.49:9000/api/generate"
	response = requests.post(API_URL, json=payload)
	return response.json()

data = query({"model": "aboba/saiga_mistral_7b", "prompt": "Почему небо голубое?", "stream": False})
data
# Out:
# {'model': 'aboba/saiga_mistral_7b',
#  'created_at': '2024-04-18T12:13:30.636116665Z',
#  'response': '\n bot: Небо голубое из-за того, что вода, входящая в состав атмосферы, поглощает и отражает свет солнца на разных длинах волн. Голубой цвет света — это комбинация синего и зеленого светов, которые доминируют в спектре света, который попадает на наш глаз через атмосферу Земли.',
#  'done': True,
#  'context': [733,
#   16289,
#   28793,
#   2775,
#   28829,
#   1040,
#   9177,
#   28819,
#   2618,
#   28725,
#   24379,
#   1789,
#   28811,
#   7763,
#   28826,
#   4086,
#   14460,
#   15481,
#   22681,
#   1622,
#   6993,
#   608,
#   6089,
#   28723,
#   2775,
#   28829,
#   5234,
#   803,
#   870,
#   892,
#   870,
#   28773,
#   28841,
#   28822,
#   698,
#   12566,
#   14599,
#   1563,
#   839,
#   21589,
#   2618,
#   28773,
#   28841,
#   28822,
#   14122,
#   28723,
#   3787,
#   1696,
#   2953,
#   2409,
#   2290,
#   1695,
#   2932,
#   2290,
#   28773,
#   28804,
#   733,
# ...
